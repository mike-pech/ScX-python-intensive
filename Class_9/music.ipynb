# %%
pip install -q pandas numpy
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./yandex_music_project.csv")

# %%
data.tail(3)
# Out:
#          userID                      Track         artist       genre  \
# 65076  C5E3A0D5                  Jalopiina            NaN  industrial
# 65077  321D0506              Freight Train  Chas McDevitt        rock
# 65078  3A64EF84  Tell Me Sweet Little Lies   Monica Lopez     country
#
#         City        time     Day
# 65076   Moscow  20:09:26  Friday
# 65077   Moscow  21:43:59  Friday
# 65078   Moscow  21:59:46  Friday

# %%
data['genre'].unique()
# Out:
# array(['rock', 'pop', 'folk', 'dance', 'rusrap', 'ruspop', 'world',
#        'electronic', nan, 'alternative', 'children', 'rnb', 'hip', 'jazz',
#        'postrock', 'latin', 'classical', 'metal', 'reggae', 'tatar',
#        'blues', 'instrumental', 'rusrock', 'dnb', 'türk', 'post',
#        'country', 'psychedelic', 'conjazz', 'indie', 'posthardcore',
#        'local', 'avantgarde', 'punk', 'videogame', 'techno', 'house',
#        'christmas', 'melodic', 'caucasian', 'reggaeton', 'soundtrack',
#        'singer', 'ska', 'shanson', 'ambient', 'film', 'western', 'rap',
#        'beats', "hard'n'heavy", 'progmetal', 'minimal', 'contemporary',
#        'new', 'soul', 'holiday', 'german', 'tropical', 'fairytail',
#        'spiritual', 'urban', 'gospel', 'nujazz', 'folkmetal', 'trance',
#        'miscellaneous', 'anime', 'hardcore', 'progressive', 'chanson',
#        'numetal', 'vocal', 'estrada', 'russian', 'classicmetal',
# ...

# %%
data["  City  "]           # А зачем пробелы? Это потому что автор датасета дол- кароч ключ в датасете такой
# Out:
# 0        Saint-Petersburg
# 1                  Moscow
# 2        Saint-Petersburg
# 3        Saint-Petersburg
# 4                  Moscow
#                ...
# 65074              Moscow
# 65075    Saint-Petersburg
# 65076              Moscow
# 65077              Moscow
# 65078              Moscow
# Name:   City  , Length: 65079, dtype: object

# %%
data.columns = [column.strip().lower() for column in data.columns]
# data.columns = data.rename(columns="userid",)

# %%
data.columns
# Out:
# Index(['userid', 'track', 'artist', 'genre', 'city', 'time', 'day'], dtype='object')

# %%
data['day'].unique()
# data["frog"] = data[data["day"] ]

# %%
# data["frog"].head()
# Out:
# 0    Quack
# 1    Quack
# 2    Quack
# 3    Quack
# 4    Quack
# Name: frog, dtype: object

# %%
_data = data.head(10)
_data["genre"] == "dance"
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: genre, dtype: bool

# %%
_data[_data["genre"] == "rock"]
# Out:
#      userid                        track            artist genre  \
# 0  FFB692EC            Kamigata To Boots  The Mass Missile  rock
# 1  55204538  Delayed Because of Accident  Andreas Rönnberg  rock
#
#                city      time        day   frog
# 0  Saint-Petersburg  20:28:33  Wednesday  Quack
# 1            Moscow  14:07:09     Friday  Quack

# %%
data[data["day"] == "Wednesday"]
# Out:
#          userid                 track            artist        genre  \
# 0      FFB692EC     Kamigata To Boots  The Mass Missile         rock
# 2        20EC38     Funiculì funiculà       Mario Lanza          pop
# 6      4CB90AA5                  True      Roman Messer        dance
# 7      F03E1C1F      Feeling This Way   Polina Griffith        dance
# 9      E772D5C0             Pessimist               NaN        dance
# ...         ...                   ...               ...          ...
# 65057  8624CE71  Treasures and Trolls        Tera Melos  alternative
# 65060  574EBCB0     Turn up the Radio         Autograph         rock
# 65061  F170C7C0         Back to Black         Soul Deep          rnb
# 65068  9E65547F    Fascinating Rhythm       Mark Murphy         jazz
# 65074  729CBB09               My Name            McLean          rnb
#
#                    city      time        day   frog
# 0      Saint-Petersburg  20:28:33  Wednesday  Quack
# ...

# %%
data[data["day"] == "Wednesday"]
# Out:
# /tmp/ipykernel_547/2682851938.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   _data[data["day"] == "Wednesday"]
#      userid              track            artist  genre              city  \
# 0  FFB692EC  Kamigata To Boots  The Mass Missile   rock  Saint-Petersburg
# 2    20EC38  Funiculì funiculà       Mario Lanza    pop  Saint-Petersburg
# 6  4CB90AA5               True      Roman Messer  dance            Moscow
# 7  F03E1C1F   Feeling This Way   Polina Griffith  dance            Moscow
# 9  E772D5C0          Pessimist               NaN  dance  Saint-Petersburg
#
#        time        day   frog
# 0  20:28:33  Wednesday  Quack
# 2  20:58:07  Wednesday  Quack
# 6  13:00:07  Wednesday  Quack
# 7  20:47:49  Wednesday  Quack
# 9  21:20:49  Wednesday  Quack

# %%
for row in _data.values:
    print(row, type(row))
# Out:
# ['FFB692EC' 'Kamigata To Boots' 'The Mass Missile' 'rock'
#  'Saint-Petersburg' '20:28:33' 'Wednesday' 'Quack'] <class 'numpy.ndarray'>
# ['55204538' 'Delayed Because of Accident' 'Andreas Rönnberg' 'rock'
#  'Moscow' '14:07:09' 'Friday' 'Quack'] <class 'numpy.ndarray'>
# ['20EC38' 'Funiculì funiculà' 'Mario Lanza' 'pop' 'Saint-Petersburg'
#  '20:58:07' 'Wednesday' 'Quack'] <class 'numpy.ndarray'>
# ['A3DD03C9' 'Dragons in the Sunset' 'Fire + Ice' 'folk' 'Saint-Petersburg'
#  '08:37:09' 'Monday' 'Quack'] <class 'numpy.ndarray'>
# ['E2DC1FAE' 'Soul People' 'Space Echo' 'dance' 'Moscow' '08:34:34'
#  'Monday' 'Quack'] <class 'numpy.ndarray'>
# ['842029A1' 'Преданная' 'IMPERVTOR' 'rusrap' 'Saint-Petersburg' '13:09:41'
#  'Friday' 'Quack'] <class 'numpy.ndarray'>
# ['4CB90AA5' 'True' 'Roman Messer' 'dance' 'Moscow' '13:00:07' 'Wednesday'
#  'Quack'] <class 'numpy.ndarray'>
# ['F03E1C1F' 'Feeling This Way' 'Polina Griffith' 'dance' 'Moscow'
# ...

# %%
data["frog"] = np.where(data["day"] == "Wednesday", "Quack", "Not Quack")
data.head()
# Out:
#      userid                        track            artist  genre  \
# 0  FFB692EC            Kamigata To Boots  The Mass Missile   rock
# 1  55204538  Delayed Because of Accident  Andreas Rönnberg   rock
# 2    20EC38            Funiculì funiculà       Mario Lanza    pop
# 3  A3DD03C9        Dragons in the Sunset        Fire + Ice   folk
# 4  E2DC1FAE                  Soul People        Space Echo  dance
#
#                city      time        day       frog
# 0  Saint-Petersburg  20:28:33  Wednesday      Quack
# 1            Moscow  14:07:09     Friday  Not Quack
# 2  Saint-Petersburg  20:58:07  Wednesday      Quack
# 3  Saint-Petersburg  08:37:09     Monday  Not Quack
# 4            Moscow  08:34:34     Monday  Not Quack

# %%
sorted(data["genre"].dropna().unique())
# Out:
# ['acid',
#  'acoustic',
#  'action',
#  'adult',
#  'africa',
#  'afrikaans',
#  'alternative',
#  'alternativepunk',
#  'ambient',
#  'americana',
#  'animated',
#  'anime',
#  'arabesk',
#  'arabic',
#  'arena',
#  'argentinetango',
#  'art',
#  'audiobook',
#  'author',
#  'avantgarde',
#  'axé',
#  'baile',
#  'balkan',
#  'beats',
#  'bigroom',
#  'black',
#  'bluegrass',
#  'blues',
#  'bollywood',
#  'bossa',
#  'brazilian',
#  'breakbeat',
#  'breaks',
#  'broadway',
#  'cantautori',
#  'cantopop',
#  'canzone',
#  'caribbean',
#  'caucasian',
#  'celtic',
#  'chamber',
#  'chanson',
#  'children',
#  'chill',
#  'chinese',
#  'choral',
#  'christian',
#  'christmas',
#  'classical',
#  'classicmetal',
#  'club',
#  'colombian',
#  'comedy',
#  'conjazz',
#  'contemporary',
#  'country',
#  'cuban',
#  'dance',
#  'dancehall',
#  'dancepop',
#  'dark',
#  'death',
#  'deep',
#  'deutschrock',
#  'deutschspr',
#  'dirty',
#  'disco',
#  'dnb',
#  'documentary',
#  'downbeat',
# ...
